# %% [markdown]
# # Yelp API - Lab
#
# The previously deployed lab on working around building a GIS with Yelp API and Folium can be found [here](https://github.com/learn-co-curriculum/dsc-2-15-10-yelp-api-gis-lab/tree/a56358c2d0c2daf569a5f50937c4c27463aadb1a) (not relevant for new students).
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, and some basic Folium visualizations its time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and perform data analysis on the data returned
# * Perform pagination to retrieve troves of data!
# * Create a simple geographical system on to view information about selected businesses, at a given location.

# %% [markdown]
# ## Problem Introduction
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a DataFrame (for further exploration) and create a map using Folium to visualize the results geographically.

# %% [markdown]
# ## Part I - Make the Initial Request
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you, but make the request below.

# %%
#Your code here
import requests
import json
import pandas as pd
import folium

# %%
api_key = 'DAXYZmYsp5tGEQ34cAkGyew5wEN5qUydpnwns-CnCdZ-UED8wqpWhOE8jipSkRxzCRg8wJbgH0_uWerUVfDohCeX0B4BpM2TrV-lEVu4y8j3Jj4ZHnr4pSgJx2CRXHYx'
term = 'Vegan'
location = 'Wall Street NY'
SEARCH_LIMIT = 50

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)
response.json()
# Out:
# {'businesses': [{'id': 'uam87TEibi2u6fjt_0JWuQ',
#    'alias': 'beyond-sushi-new-york-9',
#    'name': 'Beyond Sushi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/q-derVjYHYPosAPaJlMMFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beyond-sushi-new-york-9?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 21,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'kosher', 'title': 'Kosher'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.706433, 'longitude': -74.00766},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '70 Pine St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10270',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 Pine St', 'New York, NY 10270']},
#    'phone': '+19172614530',
#    'display_phone': '(917) 261-4530',
#    'distance': 108.11234364002036},
#   {'id': 'tdhz1FN3OdTxdDkLljySJA',
#    'alias': 'the-cinnamon-snail-new-york-9',
#    'name': 'The Cinnamon Snail',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Jl16j-soMJXd-D18IKChgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cinnamon-snail-new-york-9?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 68,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7065047, 'longitude': -74.0077715},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '70 Pine St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10270',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 Pine St', 'New York, NY 10270']},
#    'phone': '+18622466431',
#    'display_phone': '(862) 246-6431',
#    'distance': 103.62138617256029},
#   {'id': '8k21vQYd7uGHw6CDrPwCUQ',
#    'alias': 'by-chloe-seaport-district-new-york',
#    'name': 'by CHLOE. Seaport District',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RL8rrFTosMVh2p5LO4yEtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/by-chloe-seaport-district-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 37,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7065318, 'longitude': -74.0041342},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '181 Front St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Front St', 'New York, NY 10038']},
#    'phone': '+12122432235',
#    'display_phone': '(212) 243-2235',
#    'distance': 399.08926640228646},
#   {'id': 'jsWvdZdi-7oE1c9VU5qHFg',
#    'alias': 'sweetgreen-new-york-13',
#    'name': 'sweetgreen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uHjBSwyhmsTNYzyRrITcLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sweetgreen-new-york-13?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 134,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.705586, 'longitude': -74.008382},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '67 Wall St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['67 Wall St', 'New York, NY 10005']},
#    'phone': '+12124879030',
#    'display_phone': '(212) 487-9030',
#    'distance': 60.61359355413616},
#   {'id': 'FvCslLyo0SlDKI52bEDekQ',
#    'alias': 'nish-nush-new-york-5',
#    'name': 'Nish Nush',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qRsxfqwLZ0iNK20OHR6Q6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nish-nush-new-york-5?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 232,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'kosher', 'title': 'Kosher'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.709472, 'longitude': -74.007949},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '41 John St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['41 John St', 'New York, NY 10038']},
#    'phone': '+12125776474',
#    'display_phone': '(212) 577-6474',
#    'distance': 394.5109613859263},
#   {'id': 'EqZEbtu-91BdCPd4chXPVw',
#    'alias': 'magic-mix-juicery-new-york',
#    'name': 'Magic Mix Juicery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2oNSv1Ijs-DNAPzxJ9k5TQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/magic-mix-juicery-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 171,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70961, 'longitude': -74.006735},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '102 Fulton St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Fulton St', 'New York, NY 10038']},
#    'phone': '+16464540680',
#    'display_phone': '(646) 454-0680',
#    'distance': 436.34008568831877},
#   {'id': 'H6mb9qdqzOUEWz0WvpOsUA',
#    'alias': 'proper-food-new-york',
#    'name': 'Proper Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6uWFMTqlD2pyI25XNv9Cbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/proper-food-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 13,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70564, 'longitude': -74.00827},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '67 Wall St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['67 Wall St', 'New York, NY 10005']},
#    'phone': '+12122801746',
#    'display_phone': '(212) 280-1746',
#    'distance': 65.66733118239593},
#   {'id': 'ypqK8DWM8Bcs43YveSJnNw',
#    'alias': 'manhatta-new-york',
#    'name': 'Manhatta',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qh3k-_8qPSwt08uj7Th7og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manhatta-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 204,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70797, 'longitude': -74.0088899},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '28 Liberty St',
#     'address2': 'Fl 60',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['28 Liberty St', 'Fl 60', 'New York, NY 10005']},
#    'phone': '+12122305788',
#    'display_phone': '(212) 230-5788',
#    'distance': 204.54713334272063},
#   {'id': 'xefmiLAsKURFc6FDGSRgfQ',
#    'alias': 'westville-wall-st-new-york-5',
#    'name': 'Westville - Wall St',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ng8v6UkblqprLGCldwYRBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westville-wall-st-new-york-5?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 130,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70478, 'longitude': -74.00652},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '110 Wall St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Wall St', 'New York, NY 10005']},
#    'phone': '+12127414780',
#    'display_phone': '(212) 741-4780',
#    'distance': 236.96317629714514},
#   {'id': 'o2QR6wrQgTsWAMrd1sTjOA',
#    'alias': 'dig-inn-new-york-12',
#    'name': 'Dig Inn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QWaG_eccnvVY19VOfLhgFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dig-inn-new-york-12?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 223,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7042826, 'longitude': -74.011963},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '80 Broad St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Broad St', 'New York, NY 10004']},
#    'phone': '+12127764052',
#    'display_phone': '(212) 776-4052',
#    'distance': 327.7765028658176},
#   {'id': 'J4qehrNgX-8fi9-TTiVuBA',
#    'alias': 'roti-modern-mediterranean-new-york',
#    'name': 'Roti Modern Mediterranean',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ympLr9PNcvIqbzHymbSK7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roti-modern-mediterranean-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 235,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.706518, 'longitude': -74.007133},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '100 Maiden Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+19173383884',
#    'display_phone': '(917) 338-3884',
#    'distance': 152.67686400879586},
#   {'id': 'yVJc_3K4yzvKPDnxJ_3TEg',
#    'alias': 'chopt-creative-salad-new-york-25',
#    'name': 'Chopt Creative Salad',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/F0YgY4OzCJ1l1BLVQk4vGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chopt-creative-salad-new-york-25?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 174,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.70592, 'longitude': -74.0071},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '80 Pine St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Pine St', 'New York, NY 10005']},
#    'phone': '+12122480726',
#    'display_phone': '(212) 248-0726',
#    'distance': 172.7977288948762},
#   {'id': '_CBj4pv-I9hbiq35LFoNJg',
#    'alias': 'bluestone-lane-new-york-13',
#    'name': 'Bluestone Lane',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h-j8cP9e-xcJqhksP7aXwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bluestone-lane-new-york-13?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 53,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7047584413614,
#     'longitude': -74.0085431188345},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '90 Water St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 Water St', 'New York, NY 10005']},
#    'phone': '+17183746858',
#    'display_phone': '(718) 374-6858',
#    'distance': 142.01994037916205},
#   {'id': 'rQpO1Eie_zmeAOQ9s-T0sQ',
#    'alias': 'hole-in-the-wall-new-york-2',
#    'name': 'Hole in the Wall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KQwNs2HFWF0GDEGoSYgAEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hole-in-the-wall-new-york-2?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 385,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70837, 'longitude': -74.00563},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '15 Cliff St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Cliff St', 'New York, NY 10038']},
#    'phone': '+12126029991',
#    'display_phone': '(212) 602-9991',
#    'distance': 378.4505127384196},
#   {'id': 'N-85msuK0HE5qOp3BpPPEA',
#    'alias': 'cafe-arte-new-york-3',
#    'name': 'Cafe Arte',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HJf5Lcwu0RQno5-xWfPsaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-arte-new-york-3?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 43,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7053062780755,
#     'longitude': -74.0077696334368},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '75 Wall St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 Wall St', 'New York, NY 10005']},
#    'phone': '+12127470500',
#    'display_phone': '(212) 747-0500',
#    'distance': 118.77774683401883},
#   {'id': 'cBUlHFB1fk2q3WmP6o7gvA',
#    'alias': 'taim-fidi-new-york',
#    'name': 'Taim Fidi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wzc3cTPNr5I4Ve4b0iYcXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taim-fidi-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 34,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'falafel', 'title': 'Falafel'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70769, 'longitude': -74.00767},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '75 Maiden Ln',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+12122261248',
#    'display_phone': '(212) 226-1248',
#    'distance': 227.87195249099472},
#   {'id': 'ehyZHDeH7d1KOJLrOHfnEw',
#    'alias': 'melt-shop-new-york-7',
#    'name': 'Melt Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oKhmbHNB0gr0gvz6IQfQZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/melt-shop-new-york-7?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 335,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7097319537713,
#     'longitude': -74.0065573416641},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '111 Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['111 Fulton St', 'New York, NY 10038']},
#    'phone': '+16467417910',
#    'display_phone': '(646) 741-7910',
#    'distance': 454.8583810324073},
#   {'id': 'HqctC520WAFC5D-U8Ln--g',
#    'alias': 'springbone-kitchen-new-york-3',
#    'name': 'Springbone Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RjUFqbploNXU2oDHIHUqtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/springbone-kitchen-new-york-3?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70374, 'longitude': -74.01046},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '74 Pearl St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['74 Pearl St', 'New York, NY 10004']},
#    'phone': '+19176393655',
#    'display_phone': '(917) 639-3655',
#    'distance': 289.41673848423756},
#   {'id': 'uQ4HZzNarBBNcTKZSIY-vA',
#    'alias': 'black-fox-coffee-new-york',
#    'name': 'Black Fox Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JDMHFi9GJcDX5egiUxvuUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-fox-coffee-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 159,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7063449, 'longitude': -74.0076944},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '70 Pine St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10270',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 Pine St', 'New York, NY 10270']},
#    'phone': '+19177420133',
#    'display_phone': '(917) 742-0133',
#    'distance': 103.62138617256029},
#   {'id': '-tLtiP-bsd9OznXJKlLX9A',
#    'alias': 'city-acres-market-new-york-3',
#    'name': 'City Acres Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sc7A1eaeFAvpLNzOoLYTsA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-acres-market-new-york-3?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 102,
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7062610487484,
#     'longitude': -74.0077295435263},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '70 Pine St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70 Pine St', 'New York, NY 10005']},
#    'phone': '+19172614530',
#    'display_phone': '(917) 261-4530',
#    'distance': 95.80401176147714},
#   {'id': 's41IdamLoN-q6SBVcj7jtg',
#    'alias': 'cobble-and-co-new-york',
#    'name': 'Cobble & Co.',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4yraXifjqY8_9FG_iFhy1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cobble-and-co-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 17,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70701, 'longitude': -74.00356},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '19 Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Fulton St', 'New York, NY 10038']},
#    'phone': '+12123853689',
#    'display_phone': '(212) 385-3689',
#    'distance': 461.18499558738966},
#   {'id': 'igQ9CK71aQZyNXNbfNhVtQ',
#    'alias': 'cafe-11-new-york-4',
#    'name': 'Cafe 11',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OPUDR-7B0Qs4e9dU6JN2EQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-11-new-york-4?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 35,
#    'categories': [{'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7052529, 'longitude': -74.0140703},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '11 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Broadway', 'New York, NY 10004']},
#    'phone': '+12124252233',
#    'display_phone': '(212) 425-2233',
#    'distance': 450.67017439773247},
#   {'id': 'X6ftLqOVrSnk4k65AEJmrA',
#    'alias': 'sons-of-thunder-new-york-7',
#    'name': 'Sons of Thunder',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5VaGYeX1kuO04aqC_KiG2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sons-of-thunder-new-york-7?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 45,
#    'categories': [{'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'poke', 'title': 'Poke'},
#     {'alias': 'hotdog', 'title': 'Hot Dogs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7073200234724,
#     'longitude': -74.005784262168},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '225 Pearl St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['225 Pearl St', 'New York, NY 10038']},
#    'phone': '+16468220208',
#    'display_phone': '(646) 822-0208',
#    'distance': 289.1526972018617},
#   {'id': 'upJ9H46PS9mikHto0BNLDA',
#    'alias': '11-hanover-greek-new-york',
#    'name': '11 Hanover Greek',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XL4dGu7mAKFIB2cZ-m_ORw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/11-hanover-greek-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 95,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.705264, 'longitude': -74.008854},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '11 Hanover Sq',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Hanover Sq', 'New York, NY 10005']},
#    'phone': '+12127854000',
#    'display_phone': '(212) 785-4000',
#    'distance': 83.92153034646489},
#   {'id': '0LpWRWQx8Agm-mZtsOQ5gg',
#    'alias': 'neapolitan-express-new-york-4',
#    'name': 'Neapolitan Express',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zOYP9fEVLqCCfSCDclnSkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/neapolitan-express-new-york-4?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 170,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.707015, 'longitude': -74.009735},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '40 Wall St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 Wall St', 'New York, NY 10005']},
#    'phone': '+16469186169',
#    'display_phone': '(646) 918-6169',
#    'distance': 120.27924747550964},
#   {'id': 'kE-FRSgiccLIAaGAcXKG7g',
#    'alias': 'king-david-tacos-new-york-2',
#    'name': 'King David Tacos',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QOo5DFZ_ugRt6sdM7tz15A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/king-david-tacos-new-york-2?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 17,
#    'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7065887451172,
#     'longitude': -74.0096130371094},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Mannahatta Park',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Mannahatta Park', 'New York, NY 10005']},
#    'phone': '+19293678226',
#    'display_phone': '(929) 367-8226',
#    'distance': 165.46405215092526},
#   {'id': 'ogKW1k0UknvchuNsw7_5Hg',
#    'alias': 'just-salad-new-york-3',
#    'name': 'Just Salad',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FBF6yjuMNfgG1d-flCeQAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/just-salad-new-york-3?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 178,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.706812, 'longitude': -74.007107},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '100 Maiden Ln',
#     'address2': 'Ste 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Maiden Ln', 'Ste 2', 'New York, NY 10038']},
#    'phone': '+12122441111',
#    'display_phone': '(212) 244-1111',
#    'distance': 169.23354843268402},
#   {'id': '5ymqS_8YqKoND4WwfXyiAQ',
#    'alias': 'poke-green-new-york-5',
#    'name': 'Poke Green',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m8pKtQfLYSv5M4QgCs_7Ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/poke-green-new-york-5?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 166,
#    'categories': [{'alias': 'poke', 'title': 'Poke'},
#     {'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7057753, 'longitude': -74.0072424},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '164 Pearl St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['164 Pearl St', 'New York, NY 10007']},
#    'phone': '+12123610029',
#    'display_phone': '(212) 361-0029',
#    'distance': 135.70261686775146},
#   {'id': '_rzVYnChUVRaQb7VyuI7IQ',
#    'alias': 'dig-inn-new-york-5',
#    'name': 'Dig Inn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vhr-lRQnYl566pkX7mDxLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dig-inn-new-york-5?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 275,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7060753837547,
#     'longitude': -74.0071442785042},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '80 Pine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Pine St', 'New York, NY 10005']},
#    'phone': '+12127851110',
#    'display_phone': '(212) 785-1110',
#    'distance': 141.39890554649483},
#   {'id': 'USQxn9Arz6tl-4AqtqpCkg',
#    'alias': 'pita-press-new-york-4',
#    'name': 'Pita Press',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_lmpV8FMMGlGeROGtsLLdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pita-press-new-york-4?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 167,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7070857, 'longitude': -74.0080807},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '25 Cedar St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Cedar St', 'New York, NY 10005']},
#    'phone': '+12123449737',
#    'display_phone': '(212) 344-9737',
#    'distance': 134.05803746047133},
#   {'id': 'kvPJ2uAX4gcTJ2XCmlz1Kw',
#    'alias': 'juice-generation-new-york-13',
#    'name': 'Juice Generation',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vk8oYrqMs7Rv0FCXNx4dVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juice-generation-new-york-13?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 66,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.707015, 'longitude': -74.0067279267446},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '101 Maiden Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+12125311110',
#    'display_phone': '(212) 531-1110',
#    'distance': 208.28506976845028},
#   {'id': 'N9tNC3T5JMCAaS-paP6jrA',
#    'alias': 'bareburger-new-york-19',
#    'name': 'Bareburger',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nz2i5Cd4Y5zA-AkYyMkYRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bareburger-new-york-19?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 433,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7098875, 'longitude': -74.0063175},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '155 William St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['155 William St', 'New York, NY 10038']},
#    'phone': '+16466570388',
#    'display_phone': '(646) 657-0388',
#    'distance': 479.1474279651962},
#   {'id': 'EZvf07qcxg14lzaAdZaOFg',
#    'alias': 'chopt-creative-salad-co-new-york-16',
#    'name': 'Chopt Creative Salad Co.',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9JfckafOtiLAm5y_QPD0HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chopt-creative-salad-co-new-york-16?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 28,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7023139, 'longitude': -74.0114968},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1 New York Plaza',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 New York Plaza', 'New York, NY 10004']},
#    'phone': '+16467419834',
#    'display_phone': '(646) 741-9834',
#    'distance': 507.84767961960705},
#   {'id': '_hsAPjn1x58Fk-zj5uXL9A',
#    'alias': 'the-greenmarket-at-bowling-green-new-york-2',
#    'name': 'The Greenmarket At Bowling Green',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9mv3OGd0XimL5asgowjzLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-greenmarket-at-bowling-green-new-york-2?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 7,
#    'categories': [{'alias': 'farmersmarket', 'title': 'Farmers Market'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7045191, 'longitude': -74.0141263},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Bowling Green',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Bowling Green', 'New York, NY 10004']},
#    'phone': '+12127887476',
#    'display_phone': '(212) 788-7476',
#    'distance': 477.3390056719382},
#   {'id': 'k2p78r6NOhYYb_5QOORGcA',
#    'alias': 'kome-waza-new-york',
#    'name': 'Kome Waza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Z5e71qnRHbhdLYo8Xl74HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kome-waza-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 153,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'poke', 'title': 'Poke'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70351, 'longitude': -74.01024},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '40 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['40 Water St', 'New York, NY 10004']},
#    'phone': '+16463681727',
#    'display_phone': '(646) 368-1727',
#    'distance': 301.42972182803226},
#   {'id': 'btuxzhAbhuJtwTKiU7ggTw',
#    'alias': 'taz-cafe-new-york-2',
#    'name': 'Taz Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WiLGv_RAwWH6fYqGTjKhvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taz-cafe-new-york-2?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 38,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.70685, 'longitude': -74.00848},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '54 Pine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['54 Pine St', 'New York, NY 10005']},
#    'phone': '+12127428009',
#    'display_phone': '(212) 742-8009',
#    'distance': 95.18134779947877},
#   {'id': 'ZgyvDF_hOWas3SXe0Hj7hA',
#    'alias': 'schilling-new-york',
#    'name': 'Schilling',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4VZAQADQQebHoqQf5gkbJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/schilling-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 128,
#    'categories': [{'alias': 'austrian', 'title': 'Austrian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70857, 'longitude': -74.014},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '109 Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['109 Washington St', 'New York, NY 10006']},
#    'phone': '+12124061200',
#    'display_phone': '(212) 406-1200',
#    'distance': 518.8085342417478},
#   {'id': 'R3fMQtSL0MrMUyW_Q32oNw',
#    'alias': 'naya-new-york-20',
#    'name': 'NAYA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-joBzjq_FBh2ndWi_ZogxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naya-new-york-20?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 110,
#    'categories': [{'alias': 'lebanese', 'title': 'Lebanese'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7023139, 'longitude': -74.0114968},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': 'One New York Plz',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['One New York Plz', 'New York, NY 10004']},
#    'phone': '+12127608888',
#    'display_phone': '(212) 760-8888',
#    'distance': 507.84767961960705},
#   {'id': 'PbLGoaIkihF2JPnVRFtxxw',
#    'alias': 'oaxaca-taqueria-new-york-13',
#    'name': 'Oaxaca Taqueria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_CLTMjK6Aef2DwGcUzxVmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oaxaca-taqueria-new-york-13?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 65,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7054473656225,
#     'longitude': -74.0083641817509},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '87 Beaver St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['87 Beaver St', 'New York, NY 10005']},
#    'phone': '+12122320035',
#    'display_phone': '(212) 232-0035',
#    'distance': 74.20781489548128},
#   {'id': '7b2Lezmx-eyuTPoxaGwPmQ',
#    'alias': 'pressed-juicery-new-york-16',
#    'name': 'Pressed Juicery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IgquBdJlUxjTGlh4DRnCiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pressed-juicery-new-york-16?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 32,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7069751974652,
#     'longitude': -74.0073128834324},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '100 Maiden Ln',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Maiden Ln', 'New York, NY 10019']},
#    'phone': '+16469984981',
#    'display_phone': '(646) 998-4981',
#    'distance': 165.7156994387121},
#   {'id': 'LLHV4CFPy3NYPm4lr_k0Lg',
#    'alias': 'juice-press-new-york-81',
#    'name': 'Juice Press',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zp6fNJw3kjzS685z1p0Ddw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/juice-press-new-york-81?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 1,
#    'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'organic_stores', 'title': 'Organic Stores'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 40.70745, 'longitude': -74.01104},
#    'transactions': [],
#    'location': {'address1': '14 Wall St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['14 Wall St', 'New York, NY 10005']},
#    'phone': '+12127770034',
#    'display_phone': '(212) 777-0034',
#    'distance': 232.53347772229833},
#   {'id': 'hT1NOAqwYhVtQ3rrEK53MQ',
#    'alias': 'flavors-new-york-7',
#    'name': 'Flavors',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TEgfi3C8sG9At_ldmObgbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flavors-new-york-7?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 18,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70599, 'longitude': -74.01259},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '42 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Broadway', 'New York, NY 10004']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 319.8913624178122},
#   {'id': 'zjks9r34-5cw9FrONfpsCg',
#    'alias': 'the-best-of-new-york-food-new-york',
#    'name': 'The Best of New York Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DeZZ87WfaAKb5jVxWUrVNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-best-of-new-york-food-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 81,
#    'categories': [{'alias': 'delis', 'title': 'Delis'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70656, 'longitude': -74.00618},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '150 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Water St', 'New York, NY 10005']},
#    'phone': '+12129521890',
#    'display_phone': '(212) 952-1890',
#    'distance': 243.86883671694088},
#   {'id': 'aJD2o-M4lgPxcvWrANefTA',
#    'alias': 'roast-kitchen-new-york-4',
#    'name': 'Roast Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yW8O19kHoow_DJi-l3ouYA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roast-kitchen-new-york-4?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 119,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7068339839922,
#     'longitude': -74.0048267419277},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '199 Water St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['199 Water St', 'New York, NY 10038']},
#    'phone': '+12122692590',
#    'display_phone': '(212) 269-2590',
#    'distance': 348.6123554223272},
#   {'id': 'N-M-c8yQFqGW1jn_tdCzPg',
#    'alias': 'sams-falafel-stand-new-york',
#    'name': "Sam's Falafel Stand",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IEX5Ihk_1ReYvxPxpMNsqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sams-falafel-stand-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 186,
#    'categories': [{'alias': 'falafel', 'title': 'Falafel'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7090396819627,
#     'longitude': -74.0113380915443},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Cedar St And Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10006',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Cedar St And Broadway', 'New York, NY 10006']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 397.3922443449474},
#   {'id': '_XPusO4eMV3L9TiD38I4gw',
#    'alias': 'al-horno-lean-mexican-kitchen-new-york-16',
#    'name': 'Al Horno Lean Mexican Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5JO2nayxS9fIFuOVGHYCgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/al-horno-lean-mexican-kitchen-new-york-16?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 47,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7045938074589,
#     'longitude': -74.0092887729406},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '110 Pearl St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10005',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Pearl St', 'New York, NY 10005']},
#    'phone': '+12124808500',
#    'display_phone': '(212) 480-8500',
#    'distance': 158.5677846491323},
#   {'id': 'j92Fv_ee5S-szU0yeS3x8g',
#    'alias': 'lobster-gogo-new-york',
#    'name': 'Lobster GoGo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O8TkOZlDsiNs7z0Z_a4P-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lobster-gogo-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 31,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70681, 'longitude': -74.00416},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '190 Front St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['190 Front St', 'New York, NY 10038']},
#    'phone': '+12128094646',
#    'display_phone': '(212) 809-4646',
#    'distance': 372.9455248536079},
#   {'id': 'y1192qiuwi3m0tqdt1Dh7g',
#    'alias': 'sugar-momma-new-york-3',
#    'name': 'Sugar Momma',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QRqgz-TUyQ1viy3pVLwF2g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sugar-momma-new-york-3?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 40,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70837, 'longitude': -74.00563},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '15 Cliff St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Cliff St', 'New York, NY 10038']},
#    'phone': '+12126029991',
#    'display_phone': '(212) 602-9991',
#    'distance': 378.4505127384196},
#   {'id': 'B1XdGwZZ5ee2fBdngj7NUw',
#    'alias': 'underground-pizza-new-york',
#    'name': 'Underground Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gCOE3o5WufGPCaJcin5nNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/underground-pizza-new-york?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 262,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70499, 'longitude': -74.00961},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '3 Hanover Sq',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Hanover Sq', 'New York, NY 10004']},
#    'phone': '+12124254442',
#    'display_phone': '(212) 425-4442',
#    'distance': 133.7908970706008},
#   {'id': 'G-b9kvnRh0pLi4fsdcmwjg',
#    'alias': 'josephs-restaurant-new-york-112',
#    'name': "Joseph's Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AgsXuvorp8RvieccKglQcg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/josephs-restaurant-new-york-112?adjust_creative=Z-qRpY-J2xNgyt1TQTUjUA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Z-qRpY-J2xNgyt1TQTUjUA',
#    'review_count': 72,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70499, 'longitude': -74.00961},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3 Hanover Square',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3 Hanover Square', 'New York, NY 10004']},
#    'phone': '+12127471300',
#    'display_phone': '(212) 747-1300',
#    'distance': 133.7908970706008}],
#  'total': 139,
#  'region': {'center': {'longitude': -74.00882005691528,
#    'latitude': 40.706018286529755}}}

# %% [markdown]
# ## Pagination
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.josn().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data. Your final goal will be to reformat the data concerning the businesses themselves into a pandas DataFrame from the json objects.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %%
# Your code here; use a function or loop to retrieve all the results 
#from your original request

response.json()['total']
# Out:
# 139

# %%
def get_businesses():
    vegan_list = []
    api_key = 'DAXYZmYsp5tGEQ34cAkGyew5wEN5qUydpnwns-CnCdZ-UED8wqpWhOE8jipSkRxzCRg8wJbgH0_uWerUVfDohCeX0B4BpM2TrV-lEVu4y8j3Jj4ZHnr4pSgJx2CRXHYx'
    term = 'Vegan'
    location = 'Wall Street NY'
    SEARCH_LIMIT = 50

    url = 'https://api.yelp.com/v3/businesses/search'

    headers = {'Authorization': 'Bearer {}'.format(api_key)}

    for i in range(0,3):
        offset = 50*i
        url_params = {
                    'term': term.replace(' ', '+'),
                    'location': location.replace(' ', '+'),
                    'limit': SEARCH_LIMIT,
                    'offset': offset
                }
        response = requests.get(url, headers=headers, params=url_params)
        vegan_list += (response.json()['businesses'])
    
    return vegan_list

# %%
vegan_restaurants = get_businesses()

# %%
len(vegan_restaurants)
# Out:
# 139

# %%
vegan_df = pd.DataFrame(vegan_restaurants)
vegan_df.head()
# Out:
#                                 alias  \
# 0             beyond-sushi-new-york-9
# 1       the-cinnamon-snail-new-york-9
# 2  by-chloe-seaport-district-new-york
# 3              sweetgreen-new-york-13
# 4                nish-nush-new-york-5
#
#                                           categories  \
# 0  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...
# 1  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...
# 2  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...
# 3  [{'alias': 'salad', 'title': 'Salad'}, {'alias...
# 4  [{'alias': 'vegetarian', 'title': 'Vegetarian'...
#
#                                          coordinates   display_phone  \
# 0    {'latitude': 40.706433, 'longitude': -74.00766}  (917) 261-4530
# 1  {'latitude': 40.7065047, 'longitude': -74.0077...  (862) 246-6431
# 2  {'latitude': 40.7065318, 'longitude': -74.0041...  (212) 243-2235
# 3   {'latitude': 40.705586, 'longitude': -74.008382}  (212) 487-9030
# 4   {'latitude': 40.709472, 'longitude': -74.007949}  (212) 577-6474
#
#      distance                      id  \
# 0  108.112344  uam87TEibi2u6fjt_0JWuQ
# 1  103.621386  tdhz1FN3OdTxdDkLljySJA
# 2  399.089266  8k21vQYd7uGHw6CDrPwCUQ
# 3   60.613594  jsWvdZdi-7oE1c9VU5qHFg
# 4  394.510961  FvCslLyo0SlDKI52bEDekQ
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/q-derV...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/Jl16j-...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/RL8rrF...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/uHjBSw...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/qRsxfq...      False
#
#                                             location  \
# 0  {'address1': '70 Pine St', 'address2': None, '...
# 1  {'address1': '70 Pine St', 'address2': '', 'ad...
# 2  {'address1': '181 Front St', 'address2': None,...
# 3  {'address1': '67 Wall St', 'address2': None, '...
# 4  {'address1': '41 John St', 'address2': '', 'ad...
#
#                          name         phone price  rating  review_count  \
# 0                Beyond Sushi  +19172614530    $$     4.5            21
# 1          The Cinnamon Snail  +18622466431    $$     4.0            68
# 2  by CHLOE. Seaport District  +12122432235   NaN     4.0            37
# 3                  sweetgreen  +12124879030    $$     3.5           134
# 4                   Nish Nush  +12125776474    $$     4.5           232
#
#          transactions                                                url
# 0  [pickup, delivery]  https://www.yelp.com/biz/beyond-sushi-new-york...
# 1  [pickup, delivery]  https://www.yelp.com/biz/the-cinnamon-snail-ne...
# 2  [pickup, delivery]  https://www.yelp.com/biz/by-chloe-seaport-dist...
# 3  [pickup, delivery]  https://www.yelp.com/biz/sweetgreen-new-york-1...
# 4  [pickup, delivery]  https://www.yelp.com/biz/nish-nush-new-york-5?...

# %% [markdown]
# ## Exploratory Analysis
#
# Take the restaurants from the previous question and do an intial exploratory analysis. At minimum, this should include looking at the distribution of features such as price, rating and number of reviews as well as the relations between these dimensions.

# %%
#Your code here
vegan_df.describe()
# Out:
#          distance      rating  review_count
# count  139.000000  139.000000    139.000000
# mean   315.613427    3.683453    177.014388
# std    146.280825    0.521786    211.685095
# min     53.985150    1.000000      1.000000
# 25%    192.188162    3.500000     49.500000
# 50%    319.563428    3.500000    110.000000
# 75%    429.978227    4.000000    205.000000
# max    736.841110    4.500000   1517.000000

# %%
vegan_df.info()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-05af2053405b> in <module>()
# ----> 1 vegan_df.info()
#
# NameError: name 'vegan_df' is not defined

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(12,8))
plt.scatter(vegan_df['price'],vegan_df['rating'])
plt.show()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-30-e67b0484c0d8> in <module>()
# ----> 1 plt.scatter(vegan_df['price'],vegan_df['rating'])
#       2 plt.show()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4170             edgecolors = 'face'
#    4171
# -> 4172         self._process_unit_info(xdata=x, ydata=y, kwargs=kwargs)
#    4173         x = self.convert_xunits(x)
#    4174         y = self.convert_yunits(y)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/axes/_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2133             return kwargs
#    2134
# -> 2135         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
#    2136         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2137         return kwargs
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/axes/_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2116                 # We only need to update if there is nothing set yet.
#    2117                 if not axis.have_units():
# -> 2118                     axis.update_units(data)
#    2119
#    2120             # Check for units in the kwargs, and if present update axis
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/axis.py in update_units(self, data)
#    1471         neednew = self.converter != converter
#    1472         self.converter = converter
# -> 1473         default = self.converter.default_units(data, self)
#    1474         if default is not None and self.units is None:
#    1475             self.set_units(default)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/category.py in default_units(data, axis)
#     101         # default_units->axis_info->convert
#     102         if axis.units is None:
# --> 103             axis.set_units(UnitData(data))
#     104         else:
#     105             axis.units.update(data)
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/category.py in __init__(self, data)
#     167         self._counter = itertools.count()
#     168         if data is not None:
# --> 169             self.update(data)
#     170
#     171     def update(self, data):
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/matplotlib/category.py in update(self, data)
#     186         for val in OrderedDict.fromkeys(data):
#     187             if not isinstance(val, (str, bytes)):
# --> 188                 raise TypeError("{val!r} is not a string".format(val=val))
#     189             if val not in self._mapping:
#     190                 self._mapping[val] = next(self._counter)
#
# TypeError: nan is not a string

# %% [markdown]
# ## Mapping
#
# Look at the initial Yelp example and try and make a map using Folium of the restaurants you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.

# %%
#Your code here

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you synthesized your skills for the day, making multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice map visual to display the results! Well done!
